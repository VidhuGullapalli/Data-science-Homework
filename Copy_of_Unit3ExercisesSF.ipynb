# %%
# !pip install preliz
# Out:
# Collecting preliz
#   Downloading preliz-0.21.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting arviz_stats>=0.6.0 (from preliz)
#   Downloading arviz_stats-0.6.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.12/dist-packages (from preliz) (3.10.0)
# Requirement already satisfied: numba>=0.59 in /usr/local/lib/python3.12/dist-packages (from preliz) (0.60.0)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from preliz) (2.0.2)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from preliz) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->preliz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->preliz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->preliz) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->preliz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->preliz) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->preliz) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->preliz) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->preliz) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.59->preliz) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8->preliz) (1.17.0)
# Downloading preliz-0.21.0-py3-none-any.whl (519 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 13.4 MB/s eta 0:00:00
# Downloading arviz_stats-0.6.0-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: arviz_stats, preliz
# Successfully installed arviz_stats-0.6.0 preliz-0.21.0

# %%
import preliz as pz

# %% [markdown]
# # Unit 3 Exercises: Delightfully Diverse Distirbutions
#
# Use these exercises as a chance to explore the probability distributions (dists) from the pymc and preliz libraries. [Moments](https://en.wikipedia.org/wiki/Moment_(mathematics)), the main subject of these exercises, are a great way to describe dists, but there's another  way: [maximum entropy](https://en.wikipedia.org/wiki/Maximum_entropy_probability_distribution#Other_examples), which, although important, we will not cover in detail.
#
# Here's what we'll cover in this Unit's exercises:
# - The first four moments: mean, variance, skew, and kurtosis, as well as the support.
# - Single variable continuous distributions.
# - Single variable discrete distriutions
#
#
# Why do we need to know this stuff? Two reasons:
# - Probability distributions are required to set priors and likelihoods in pymc.
# - Randomness and uncertainty are not well defined mathematically, but probability and probability distributions are.
#
# With that in mind, think of these exercises as an oppurtunity to explore the ways we can be uncertain, or the ways things can be random.

# %% [markdown]
# ## The First Four Moments: Mean, Variance, Skew, and Kurtosis
#
# When we talk about a probablity dist, we often care about at four things:
# - The expected value, or where a distribution is centered (mean)
# - The amount of variation from that centered value (variation)
# - Whether or not our distribution favors, leans towards, or skews towards certain values. (skew)
# - How often to expect unusually high or low values. (kurtosis)

# %% [markdown]
# ### Playing with Beta

# %% [markdown]
# **Task1**:
#
# Plot a [preliZ Beta distribution](https://preliz.readthedocs.io/en/latest/api_reference.html#preliz.distributions.beta.Beta) with $α=1$ and $β=1$.

# %%
pz.Beta(alpha=1,beta=1).plot_pdf()
# Out:
# <Axes: >

# %% [markdown]
# **Task2**:
#
# Find the mean, variance, skew, and kurtosis of a $Beta(1,1)$ distribution. This is the same as asking for the first four moments of a $Beta(1,1)$ distribution.
#
# *Hint*: preliZ has built in function that does this for you.

# %%
# based on matchd from privious season he won 29/43 matches
FT_prior = pz.Beta(alpha=1,beta=1)


#the mean mean first, then median, and finally mode
FT_prior.mean(), FT_prior.var(), FT_prior.skewness(),FT_prior.kurtosis()
# Out:
# (np.float64(0.5), np.float64(0.08333333333333333), array(0.), np.float64(-1.2))

# %% [markdown]
# **Task3**:
#
# Plot the following distributions on seperate graphs: $Beta(1,1)$, $Beta(0.9,0.9)$, $Beta(2,1)$, $Beta(1,2)$, $Beta(7,11)$, $Beta(96,42)$, $Beta(5,5)$, $Beta(500,500)$, $Beta(0.8,0.9)$.
#
# Then, determine which of those distribtuions has:
# - the largest/smallest mean
# - the largest/smallest variance
# - the largest/smallest skew
# - the largest/smallest kurtosis
#
# and show the code you used to find that information.

# %%
d= pz.Beta(alpha=1,beta=1)
e=pz.Beta(alpha=0.9,beta=0.9)
f=pz.Beta(alpha=2,beta=1)
g=pz.Beta(alpha=1,beta=2)
h=pz.Beta(alpha=7,beta=11)
i=pz.Beta(alpha=96,beta=42)
j=pz.Beta(alpha=5,beta=5)
k=pz.Beta(alpha=500,beta=500)
h=pz.Beta(alpha=0.8,beta=0.9)
list1=[d.mean(),e.mean(),f.mean(),g.mean(),h.mean(),i.mean(),j.mean(),k.mean(),h.mean()]
lmean=max(list1)
Smean=min(list1)
list2=[d.var(),e.var(),f.var(),g.var(),h.var(),i.var(),j.var(),k.var(),h.var()]
lva=max(list2)
Sva=min(list2)
list3=[d.skewness(),e.skewness(),f.skewness(),g.skewness(),h.skewness(),i.skewness(),j.skewness(),k.skewness(),h.skewness()]
lsk=max(list3)
Ssk=min(list3)
list4=[d.kurtosis(),e.kurtosis(),f.kurtosis(),g.kurtosis(),h.kurtosis(),i.kurtosis(),j.kurtosis(),k.kurtosis(),h.kurtosis()]
lk=max(list4)
Sk=min(list4)
print("Largest mean: ",lmean)
print("Smallest mean: ",Smean)
print("Largest var: ",lva)
print("Smolest var: ",Sva)
print("Largest Skew: ",lsk)
print("Smolest Skew: ",Ssk)
print("Largest k: ",lk)
print("Smolest k: ",Sk)
# Out:
# Largest mean:  0.6956521739130435
# Smallest mean:  0.3333333333333333
# Largest var:  0.09227220299884659
# Smolest var:  0.00024975024975024975
# Largest Skew:  0.565685424949238
# Smolest Skew:  -0.565685424949238
# Largest k:  -0.005982053838484547
# Smolest k:  -1.263657274295572

# %% [markdown]
# ###Playing with other Continuous Distributions
#
# For the remaining tasks, make sure to continue to use the [preliZ documentation](https://preliz.readthedocs.io/en/latest/api_reference.html).
#
# The [wikipedia pages for each of the probability distributions](https://en.wikipedia.org/wiki/List_of_probability_distributions) are also great resources.
#
# [Wolfram Alpha](https://www.wolframalpha.com/examples/mathematics/probability/probability-distributions) is another great resource as well.

# %% [markdown]
# **Task4**:
#
# Plot the pdfs of each of the following distributions on the same graph: $Normal(μ=0,σ=1)$, $StudentT(ν=5,μ=0,σ=1)$
#
# Then, plot these on the same graph: $Exponential(λ=1/2)$, $Gamma(α=2,β=1)$, $HalfStudentT(ν=5,σ1)$
#
# For the t distribution and half t, use
#
# ```
# support=(-4,4)
# ```
# and
# ```
# support=(0,4)
# ```
# respectively, inside the plot_pdf function.

# %%
n=pz.Normal(mu=0,sigma=1)
s=pz.StudentT(nu=5,mu=0,sigma=1)

n.plot_pdf()
s.plot_pdf()
# Out:
# <Axes: >

# %%
e=pz.Exponential(lam=1/2)
g=pz.Gamma(alpha=2,beta=1)
v=pz.HalfStudentT(nu=5,sigma=1)
e.plot_pdf()
g.plot_pdf()
v.plot_pdf()
list=[n.mean(),s.mean(),e.mean(),g.mean(),v.mean()]
# Out:
# <Axes: >

# %% [markdown]
# **Task5:**
#
# Find the first four moments of the the distributions from Task4. Then,
#
# Determine which of those five dsitributions has the largest and smallest: mean, variance, skew, and kurtosis. (Ignore skew and kurtosis for the Half StudentT)
#
# Those distributions are repeated here for conveniencce: $Normal(μ=0,σ=1)$, $StudentT(ν=5,μ=0,σ=1)$,  $Exponential(λ=1/2)$, $Gamma(α=2,β=1)$, $HalfStudentT(ν=5,σ=1)$

# %% [markdown]
# Largest mean:gamma
# Smolest mean: normal
# Laergest var:gamma
# Smallest var: student
# Largest skew: Normal
# Smallest skew:Gamma
# Smallest kitosis:gamma
# Larges kitosis:normal

# %% [markdown]
# **Task6**:
#
# What x values do the Exponenital, Gamma, HalfSutdentT, and HalfNormal functions support? Why plot them on the same graph?
#
# What x values do the Normal and T distribution support? Why plot them on the same graph?
#
# What x values does the Beta distribution support?

# %% [markdown]
# 1. 0-17.5 polt them on same graph to compare their mens, skews , var, and ks.
# 2.-10-10 polt them on sma egraph to compare their mens, skews , var, and ks.
# 3. 0-1

# %% [markdown]
# **Task7**:
#
# Can a distribution with support $[0,∞]$ have negative (or left) skew? If so, plot that specific distribution.

# %% [markdown]
# *no*

# %% [markdown]
# **Task8**:
#
# Name a distribution that supports the real numbers with variance equal to 1, 0 skew, and 0 kurtosis.

# %% [markdown]
# var=1,skew=0, kurtosis=0- normal

# %% [markdown]
# **Task9**:
#
# Name a distribution with support $(-∞,∞)$ and that has negative skew.

# %% [markdown]
# normal distribution-

# %% [markdown]
# **Optional Task**:
#
# What are the maximum entropy conditions for the normal and gamma distributions?

# %% [markdown]
# ###Playing with Discrete Distributions

# %% [markdown]
# **Task9**:
#
# Plot the pdfs (techincally the pmfs) of the following distributions: $Bernoulli(p=0.7)$, $Binomial(n=10,p=0.7)$, $Poisson(μ=7)$, $Geometric(p=0.7)$, $HyperGeometric(N=50,k=35,n=15)$, $Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4])$
#
# Additionally, compute the first four moments for all those distributions--except the Categorical distribution.

# %%
b=pz.Bernoulli(p=0.7)
bi=pz.Binomial(n=10,p=0.7)
g=pz.Geometric(p=0.7)
hg=pz.HyperGeometric(N=50,k=35,n=15)
c=pz.Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4])
b.plot_pdf()
bi.plot_pdf()
g.plot_pdf()

c.plot_pdf()
hg.plot_pdf()
# Out:
# <Axes: >

# %% [markdown]
# bernouli-up
# binommial-starting up
# Geometric-down
# Hyper-up

# %% [markdown]
# **Task10**:
#
# Describe what processes "generate" each of the previous discrete distributions models. Also report their support.
#
# Here's a spicier way to phrase the question: describe these distributions' maximum entropy conditions in english.
#
# Hint: Make sure to read any of the: preliZ documentation, relevant wikipedia articles, or wolfram alpha.

# %% [markdown]
# Bernoli:recursive formula, binomial:two term expression, Geometric: trial and error, Hyper geometric:sampling without replacement Categorial: assiognes a probalilty to each oputcome
